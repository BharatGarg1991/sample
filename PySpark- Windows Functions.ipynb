# %%
print("HI")

# %%
import findspark

# %%
import pyspark
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
c= pyspark.SparkConf().setAppName("test_app").setMaster("local")
sc=pyspark.SparkContext(conf = c)
spark = SparkSession(sc)

# %%
from pyspark.sql.functions import *
from pyspark.sql.window import *

# %%
data = spark.read.csv("C:\\Users\\bgarg\\Downloads\\student_info.csv",header=True,inferSchema=True)

# %%
data.show()

# %%
data=data.withColumn("rank",rank().over(Window.orderBy(desc("Marks"))))

# %%
data.show()

# %%
data=data.withColumn("Dense_Rank",dense_rank().over(Window.orderBy(desc("Marks"))))

# %%
data.show()

# %%
data=data.withColumn("Row_Number",row_number().over(Window.orderBy(desc("Marks"))))

# %%
data.show()

# %%
data = spark.read.csv("C:\\Users\\bgarg\\Downloads\\student_info1.csv",header=True,inferSchema=True)

# %%
data.show()

# %%
data=data.withColumn("rank",rank().over(Window.partitionBy("MEDIUM").orderBy(desc("MARKS"))))

# %%
data.show()

# %%
data=data.withColumn("dense_rank",dense_rank().over(Window.partitionBy("MEDIUM").orderBy(desc("MARKS"))))

# %%
data=data.withColumn("rank_number",row_number().over(Window.partitionBy("MEDIUM").orderBy(desc("MARKS"))))

# %%
data.show()

# %%
data = spark.read.csv("C:\\Users\\bgarg\\Downloads\\sales_info.csv",header=True,inferSchema=True)

# %%
data.show()

# %%
data=data.withColumn("prvs_sales",lag("T_Sales").over(Window.orderBy(asc("C_Year")) ))

# %%
data.show()

# %%
data=data.withColumn("YOY",((col("T_Sales")-col("prvs_sales"))/col("prvs_sales")*100))

# %%
data.show()

# %%
data = spark.read.csv("C:\\Users\\bgarg\\Downloads\\sales_info_1.csv",header=True,inferSchema=True)

# %%
data.show()

# %%
data=data.withColumn("previous_year",lag("T_Sales").over(Window.partitionBy("Dept").orderBy(asc("C_Year"))))

# %%
data.show()

# %%
data=data.withColumn("YOY",((col("T_Sales")-col("previous_year"))/col("previous_year")*100))

# %%
data.show()
