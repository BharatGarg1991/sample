# %%
additionL = lambda a,b : a+b

# %%
additionL(5,6)
# Out:
# 11

# %%
squareL = lambda a : a*a

# %%
squareL(5)
# Out:
# 25

# %%
transactionT = lambda a :  "Gold" if a >2500 else ("Silver" if a>1500  else "Bronze")

# %%
transactionT(1501)
# Out:
# 'Silver'

# %%
import shutil as s
import os
import platform

# %%
s.move("C:\\Users\\bgarg\\OneDrive\\Desktop\\src\\in.txt","C:\\Users\\bgarg\\OneDrive\\Desktop\\target")
# Out:
# 'C:\\Users\\bgarg\\OneDrive\\Desktop\\target\\in.txt'

# %%
s.copy("C:\\Users\\bgarg\\OneDrive\\Desktop\\target\\in.txt","C:\\Users\\bgarg\\OneDrive\\Desktop\\src")
# Out:
# 'C:\\Users\\bgarg\\OneDrive\\Desktop\\src\\in.txt'

# %%
os.getlogin()
# Out:
# 'bgarg'

# %%
platform.system()
# Out:
# 'Windows'

# %%
platform.node()
# Out:
# 'LAPTOP-9KBKS8TE'

# %%
platform.version()
# Out:
# '10.0.26100'

# %%
platform.processor()
# Out:
# 'AMD64 Family 23 Model 104 Stepping 1, AuthenticAMD'

# %%
platform.python_version()
# Out:
# '3.11.5'

# %%
import numpy as np

# %%
np.absolute(-9)
# Out:
# 9

# %%
np.add(5,6)
# Out:
# 11

# %%
np.subtract(9,2)
# Out:
# 7

# %%
b = np.array([1,6,9,45])

# %%
b
# Out:
# array([ 1,  6,  9, 45])

# %%
b = np.array([[1,6,9,45],[6,7,98,34]])

# %%
b
# Out:
# array([[ 1,  6,  9, 45],
#        [ 6,  7, 98, 34]])

# %%
b[1]
# Out:
# array([ 6,  7, 98, 34])

# %%
b[0]
# Out:
# array([ 1,  6,  9, 45])

# %%
b[0][1]
# Out:
# 6

# %%
b[1][2]
# Out:
# 98

# %%
b=np.array([[[89,44],[1,65],[56,98]]])

# %%
b
# Out:
# array([[[89, 44],
#         [ 1, 65],
#         [56, 98]]])

# %%
np.sin(90)
# Out:
# 0.8939966636005579

# %%
np.sin(0)
# Out:
# 0.0

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\bgarg\\Downloads\\Emp1.csv",encoding='latin-1')

# %%
data.head()
# Out:
#    EmployeeID  ManagerID             Title MaritalStatus Gender  \
# 0           1         16    Gustavo Achong             M      M
# 1           2          6    Catherine Abel             S      M
# 2           3         12   Kim Abercrombie             M      M
# 3           4          3  Humberto Acevedo             S      M
# 4           5        263    Pilar Ackerman             M      M
#
#            HireDate            Dept   Job Grade
# 0  02-02-2013 00:00           Sales       Admin
# 1  31-08-2013 00:00           Sales  Management
# 2  16-06-2014 00:00         Finance       Admin
# 3  10-07-2014 00:00       Logistics       Admin
# 4  16-07-2014 00:00  Human Resource       Admin

# %%
data["MaritalStatus"]= np.where(data["MaritalStatus"]=="M","Married","Single")

# %%
data.head()
# Out:
#    EmployeeID  ManagerID             Title MaritalStatus Gender  \
# 0           1         16    Gustavo Achong       Married      M
# 1           2          6    Catherine Abel        Single      M
# 2           3         12   Kim Abercrombie       Married      M
# 3           4          3  Humberto Acevedo        Single      M
# 4           5        263    Pilar Ackerman       Married      M
#
#            HireDate            Dept   Job Grade
# 0  02-02-2013 00:00           Sales       Admin
# 1  31-08-2013 00:00           Sales  Management
# 2  16-06-2014 00:00         Finance       Admin
# 3  10-07-2014 00:00       Logistics       Admin
# 4  16-07-2014 00:00  Human Resource       Admin

# %%
import mysql
import pmysql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[78], line 2
#       1 import mysql
# ----> 2 import pmysql
#
# ModuleNotFoundError: No module named 'pmysql'

# %%
# !pip install pmysql
# Out:
# ERROR: Could not find a version that satisfies the requirement pmysql (from versions: none)
# ERROR: No matching distribution found for pmysql

# %%
import sqlalchemy
# !pip install mysql

# %%
from sqlalchemy import create_engine

# %%
sqlengine = create_engine("mysql://root:admin@localhost/amazon_db")

# %%
dbconnection = sqlengine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
squares=[]
for i in range(1,11):
    squares.append(i**2)
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
square = [i**2 for i in range(1,11)]

# %%
square
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
l = [5,66,78,99]

# %%
odd_sq = [i**2 for i in l if i%2!=0]

# %%
odd_sq
# Out:
# [25, 9801]
